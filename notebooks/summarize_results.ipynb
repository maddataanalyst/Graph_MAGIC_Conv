# %% [markdown]
# # Intro
#
# This notebook is used to visualize and manipulate results of the study. It should be run after the `dvc repro` command was successfully executed.

# %% [markdown]
# # Load libs

# %%
import os
import pandas as pd
import yaml
from IPython.display import display, Markdown

import autoroot
import autorootcwd

# %%
import aml_magic.src.consts as cc
import aml_magic.src.models.metrics as model_metrics
import aml_magic.src.utils.configs as cfg
import aml_magic.src.stages.summarize_results as sumres

# %% [markdown]
# # Load data

# %% [markdown]
# ## Load config

# %%
config_yaml = yaml.safe_load(open(f"{cc.MAIN_PARAMS_FILE}.yaml", "r"))
config = cfg.ExperimentConfig(**config_yaml)

# %% [markdown]
# ## Load summary data

# %%
summary_data = pd.read_csv(cc.STUDY_COMPARISON_PATH / "scores_summary.csv")
summary_data.head(3)
# Out:
#       dataset     metric   scope              GCN          GCN+XGB  \
# 0  AMLSim 101         F1  Ilicit  0.810 +/- 0.035  0.814 +/- 0.032
# 1  AMLSim 101         F1   Macro  0.894 +/- 0.020  0.898 +/- 0.018
# 2  AMLSim 101  Precision  Ilicit  0.724 +/- 0.058  0.786 +/- 0.052
#
#        SkipGCN+XGB          SkipGCN         Nenn+XGB             Nenn  \
# 0  0.812 +/- 0.030  0.807 +/- 0.033  0.837 +/- 0.027  0.725 +/- 0.041
# 1  0.896 +/- 0.017  0.892 +/- 0.019  0.910 +/- 0.015  0.844 +/- 0.024
# 2  0.779 +/- 0.050  0.719 +/- 0.056  0.828 +/- 0.035  0.592 +/- 0.051
#
#          MAGIC+XGB
# 0  0.865 +/- 0.016
# 1  0.925 +/- 0.009
# 2  0.944 +/- 0.013

# %% [markdown]
# ## Load raw scores per dataset

# %%
all_raw_scores = []
for dataset in os.listdir(cc.STUDY_RESULTS_PATH):
    dataset_raw_scores = pd.read_csv(cc.STUDY_RESULTS_PATH / dataset / f"{dataset}_MAGIC+xgboost_raw.csv", index_col=0).drop(columns='model')
    dataset_raw_scores["dataset"] = dataset
    all_raw_scores.append(dataset_raw_scores)

all_raw_scores_df = pd.concat(all_raw_scores, ignore_index=True)

# %% [markdown]
# # Show results

# %% [markdown]
# ## Summaries

# %%
sorting_order = [f"AMLSim {num}" for num in [31, 51, 101, 201]]
summarized_datasets = summary_data.pivot_table(
    index=['dataset', 'metric', 'scope'],
    aggfunc='max'
)

for ds in sorting_order:
    display(Markdown(f"### {ds}"))
    display(summarized_datasets.loc[ds].style.highlight_max(color='lightgreen', axis=1) )
# Out:
# ### AMLSim 31
# <style type="text/css">
# #T_46418_row0_col2, #T_46418_row1_col2, #T_46418_row2_col2, #T_46418_row3_col2, #T_46418_row4_col0, #T_46418_row4_col5, #T_46418_row5_col0, #T_46418_row5_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_46418">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46418_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_46418_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_46418_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_46418_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_46418_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_46418_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_46418_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46418_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_46418_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_46418_row0_col0" class="data row0 col0" >0.947 +/- 0.001</td>
#       <td id="T_46418_row0_col1" class="data row0 col1" >0.949 +/- 0.011</td>
#       <td id="T_46418_row0_col2" class="data row0 col2" >0.956 +/- 0.018</td>
#       <td id="T_46418_row0_col3" class="data row0 col3" >0.933 +/- 0.021</td>
#       <td id="T_46418_row0_col4" class="data row0 col4" >0.946 +/- 0.017</td>
#       <td id="T_46418_row0_col5" class="data row0 col5" >0.948 +/- 0.002</td>
#       <td id="T_46418_row0_col6" class="data row0 col6" >0.948 +/- 0.010</td>
#     </tr>
#     <tr>
#       <th id="T_46418_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_46418_row1_col0" class="data row1 col0" >0.962 +/- 0.001</td>
#       <td id="T_46418_row1_col1" class="data row1 col1" >0.964 +/- 0.008</td>
#       <td id="T_46418_row1_col2" class="data row1 col2" >0.966 +/- 0.014</td>
#       <td id="T_46418_row1_col3" class="data row1 col3" >0.951 +/- 0.015</td>
#       <td id="T_46418_row1_col4" class="data row1 col4" >0.961 +/- 0.013</td>
#       <td id="T_46418_row1_col5" class="data row1 col5" >0.962 +/- 0.001</td>
#       <td id="T_46418_row1_col6" class="data row1 col6" >0.963 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_46418_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_46418_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_46418_row2_col0" class="data row2 col0" >0.913 +/- 0.002</td>
#       <td id="T_46418_row2_col1" class="data row2 col1" >0.928 +/- 0.010</td>
#       <td id="T_46418_row2_col2" class="data row2 col2" >0.965 +/- 0.012</td>
#       <td id="T_46418_row2_col3" class="data row2 col3" >0.894 +/- 0.023</td>
#       <td id="T_46418_row2_col4" class="data row2 col4" >0.918 +/- 0.024</td>
#       <td id="T_46418_row2_col5" class="data row2 col5" >0.913 +/- 0.003</td>
#       <td id="T_46418_row2_col6" class="data row2 col6" >0.927 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_46418_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_46418_row3_col0" class="data row3 col0" >0.953 +/- 0.001</td>
#       <td id="T_46418_row3_col1" class="data row3 col1" >0.958 +/- 0.006</td>
#       <td id="T_46418_row3_col2" class="data row3 col2" >0.965 +/- 0.012</td>
#       <td id="T_46418_row3_col3" class="data row3 col3" >0.941 +/- 0.015</td>
#       <td id="T_46418_row3_col4" class="data row3 col4" >0.954 +/- 0.014</td>
#       <td id="T_46418_row3_col5" class="data row3 col5" >0.953 +/- 0.002</td>
#       <td id="T_46418_row3_col6" class="data row3 col6" >0.957 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_46418_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_46418_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_46418_row4_col0" class="data row4 col0" >0.984 +/- 0.000</td>
#       <td id="T_46418_row4_col1" class="data row4 col1" >0.971 +/- 0.020</td>
#       <td id="T_46418_row4_col2" class="data row4 col2" >0.963 +/- 0.029</td>
#       <td id="T_46418_row4_col3" class="data row4 col3" >0.975 +/- 0.030</td>
#       <td id="T_46418_row4_col4" class="data row4 col4" >0.976 +/- 0.021</td>
#       <td id="T_46418_row4_col5" class="data row4 col5" >0.984 +/- 0.000</td>
#       <td id="T_46418_row4_col6" class="data row4 col6" >0.970 +/- 0.019</td>
#     </tr>
#     <tr>
#       <th id="T_46418_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_46418_row5_col0" class="data row5 col0" >0.973 +/- 0.001</td>
#       <td id="T_46418_row5_col1" class="data row5 col1" >0.970 +/- 0.010</td>
#       <td id="T_46418_row5_col2" class="data row5 col2" >0.968 +/- 0.016</td>
#       <td id="T_46418_row5_col3" class="data row5 col3" >0.963 +/- 0.017</td>
#       <td id="T_46418_row5_col4" class="data row5 col4" >0.970 +/- 0.012</td>
#       <td id="T_46418_row5_col5" class="data row5 col5" >0.973 +/- 0.001</td>
#       <td id="T_46418_row5_col6" class="data row5 col6" >0.969 +/- 0.009</td>
#     </tr>
#   </tbody>
# </table>
# ### AMLSim 51
# <style type="text/css">
# #T_99955_row0_col2, #T_99955_row1_col2, #T_99955_row2_col2, #T_99955_row3_col2, #T_99955_row4_col5, #T_99955_row5_col0, #T_99955_row5_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99955">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99955_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_99955_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_99955_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_99955_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_99955_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_99955_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_99955_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99955_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_99955_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_99955_row0_col0" class="data row0 col0" >0.901 +/- 0.011</td>
#       <td id="T_99955_row0_col1" class="data row0 col1" >0.905 +/- 0.019</td>
#       <td id="T_99955_row0_col2" class="data row0 col2" >0.915 +/- 0.015</td>
#       <td id="T_99955_row0_col3" class="data row0 col3" >0.872 +/- 0.023</td>
#       <td id="T_99955_row0_col4" class="data row0 col4" >0.895 +/- 0.025</td>
#       <td id="T_99955_row0_col5" class="data row0 col5" >0.902 +/- 0.012</td>
#       <td id="T_99955_row0_col6" class="data row0 col6" >0.904 +/- 0.017</td>
#     </tr>
#     <tr>
#       <th id="T_99955_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_99955_row1_col0" class="data row1 col0" >0.939 +/- 0.007</td>
#       <td id="T_99955_row1_col1" class="data row1 col1" >0.941 +/- 0.012</td>
#       <td id="T_99955_row1_col2" class="data row1 col2" >0.946 +/- 0.010</td>
#       <td id="T_99955_row1_col3" class="data row1 col3" >0.921 +/- 0.014</td>
#       <td id="T_99955_row1_col4" class="data row1 col4" >0.936 +/- 0.016</td>
#       <td id="T_99955_row1_col5" class="data row1 col5" >0.939 +/- 0.008</td>
#       <td id="T_99955_row1_col6" class="data row1 col6" >0.941 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_99955_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_99955_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_99955_row2_col0" class="data row2 col0" >0.840 +/- 0.021</td>
#       <td id="T_99955_row2_col1" class="data row2 col1" >0.878 +/- 0.024</td>
#       <td id="T_99955_row2_col2" class="data row2 col2" >0.942 +/- 0.014</td>
#       <td id="T_99955_row2_col3" class="data row2 col3" >0.823 +/- 0.031</td>
#       <td id="T_99955_row2_col4" class="data row2 col4" >0.873 +/- 0.043</td>
#       <td id="T_99955_row2_col5" class="data row2 col5" >0.840 +/- 0.022</td>
#       <td id="T_99955_row2_col6" class="data row2 col6" >0.876 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_99955_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_99955_row3_col0" class="data row3 col0" >0.917 +/- 0.010</td>
#       <td id="T_99955_row3_col1" class="data row3 col1" >0.931 +/- 0.013</td>
#       <td id="T_99955_row3_col2" class="data row3 col2" >0.942 +/- 0.014</td>
#       <td id="T_99955_row3_col3" class="data row3 col3" >0.903 +/- 0.016</td>
#       <td id="T_99955_row3_col4" class="data row3 col4" >0.928 +/- 0.022</td>
#       <td id="T_99955_row3_col5" class="data row3 col5" >0.917 +/- 0.011</td>
#       <td id="T_99955_row3_col6" class="data row3 col6" >0.931 +/- 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_99955_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_99955_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_99955_row4_col0" class="data row4 col0" >0.973 +/- 0.004</td>
#       <td id="T_99955_row4_col1" class="data row4 col1" >0.933 +/- 0.029</td>
#       <td id="T_99955_row4_col2" class="data row4 col2" >0.928 +/- 0.025</td>
#       <td id="T_99955_row4_col3" class="data row4 col3" >0.927 +/- 0.032</td>
#       <td id="T_99955_row4_col4" class="data row4 col4" >0.919 +/- 0.028</td>
#       <td id="T_99955_row4_col5" class="data row4 col5" >0.974 +/- 0.003</td>
#       <td id="T_99955_row4_col6" class="data row4 col6" >0.934 +/- 0.029</td>
#     </tr>
#     <tr>
#       <th id="T_99955_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_99955_row5_col0" class="data row5 col0" >0.966 +/- 0.003</td>
#       <td id="T_99955_row5_col1" class="data row5 col1" >0.952 +/- 0.015</td>
#       <td id="T_99955_row5_col2" class="data row5 col2" >0.951 +/- 0.011</td>
#       <td id="T_99955_row5_col3" class="data row5 col3" >0.941 +/- 0.016</td>
#       <td id="T_99955_row5_col4" class="data row5 col4" >0.945 +/- 0.014</td>
#       <td id="T_99955_row5_col5" class="data row5 col5" >0.966 +/- 0.003</td>
#       <td id="T_99955_row5_col6" class="data row5 col6" >0.952 +/- 0.014</td>
#     </tr>
#   </tbody>
# </table>
# ### AMLSim 101
# <style type="text/css">
# #T_36428_row0_col2, #T_36428_row1_col2, #T_36428_row2_col2, #T_36428_row3_col2, #T_36428_row4_col3, #T_36428_row5_col0, #T_36428_row5_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_36428">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36428_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_36428_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_36428_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_36428_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_36428_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_36428_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_36428_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36428_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_36428_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_36428_row0_col0" class="data row0 col0" >0.810 +/- 0.035</td>
#       <td id="T_36428_row0_col1" class="data row0 col1" >0.814 +/- 0.032</td>
#       <td id="T_36428_row0_col2" class="data row0 col2" >0.865 +/- 0.016</td>
#       <td id="T_36428_row0_col3" class="data row0 col3" >0.725 +/- 0.041</td>
#       <td id="T_36428_row0_col4" class="data row0 col4" >0.837 +/- 0.027</td>
#       <td id="T_36428_row0_col5" class="data row0 col5" >0.807 +/- 0.033</td>
#       <td id="T_36428_row0_col6" class="data row0 col6" >0.812 +/- 0.030</td>
#     </tr>
#     <tr>
#       <th id="T_36428_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_36428_row1_col0" class="data row1 col0" >0.894 +/- 0.020</td>
#       <td id="T_36428_row1_col1" class="data row1 col1" >0.898 +/- 0.018</td>
#       <td id="T_36428_row1_col2" class="data row1 col2" >0.925 +/- 0.009</td>
#       <td id="T_36428_row1_col3" class="data row1 col3" >0.844 +/- 0.024</td>
#       <td id="T_36428_row1_col4" class="data row1 col4" >0.910 +/- 0.015</td>
#       <td id="T_36428_row1_col5" class="data row1 col5" >0.892 +/- 0.019</td>
#       <td id="T_36428_row1_col6" class="data row1 col6" >0.896 +/- 0.017</td>
#     </tr>
#     <tr>
#       <th id="T_36428_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_36428_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_36428_row2_col0" class="data row2 col0" >0.724 +/- 0.058</td>
#       <td id="T_36428_row2_col1" class="data row2 col1" >0.786 +/- 0.052</td>
#       <td id="T_36428_row2_col2" class="data row2 col2" >0.944 +/- 0.013</td>
#       <td id="T_36428_row2_col3" class="data row2 col3" >0.592 +/- 0.051</td>
#       <td id="T_36428_row2_col4" class="data row2 col4" >0.828 +/- 0.035</td>
#       <td id="T_36428_row2_col5" class="data row2 col5" >0.719 +/- 0.056</td>
#       <td id="T_36428_row2_col6" class="data row2 col6" >0.779 +/- 0.050</td>
#     </tr>
#     <tr>
#       <th id="T_36428_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_36428_row3_col0" class="data row3 col0" >0.858 +/- 0.029</td>
#       <td id="T_36428_row3_col1" class="data row3 col1" >0.885 +/- 0.026</td>
#       <td id="T_36428_row3_col2" class="data row3 col2" >0.944 +/- 0.013</td>
#       <td id="T_36428_row3_col3" class="data row3 col3" >0.793 +/- 0.026</td>
#       <td id="T_36428_row3_col4" class="data row3 col4" >0.906 +/- 0.018</td>
#       <td id="T_36428_row3_col5" class="data row3 col5" >0.855 +/- 0.028</td>
#       <td id="T_36428_row3_col6" class="data row3 col6" >0.882 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_36428_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_36428_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_36428_row4_col0" class="data row4 col0" >0.920 +/- 0.009</td>
#       <td id="T_36428_row4_col1" class="data row4 col1" >0.846 +/- 0.040</td>
#       <td id="T_36428_row4_col2" class="data row4 col2" >0.826 +/- 0.025</td>
#       <td id="T_36428_row4_col3" class="data row4 col3" >0.936 +/- 0.032</td>
#       <td id="T_36428_row4_col4" class="data row4 col4" >0.847 +/- 0.045</td>
#       <td id="T_36428_row4_col5" class="data row4 col5" >0.920 +/- 0.010</td>
#       <td id="T_36428_row4_col6" class="data row4 col6" >0.847 +/- 0.032</td>
#     </tr>
#     <tr>
#       <th id="T_36428_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_36428_row5_col0" class="data row5 col0" >0.942 +/- 0.005</td>
#       <td id="T_36428_row5_col1" class="data row5 col1" >0.911 +/- 0.020</td>
#       <td id="T_36428_row5_col2" class="data row5 col2" >0.908 +/- 0.012</td>
#       <td id="T_36428_row5_col3" class="data row5 col3" >0.936 +/- 0.017</td>
#       <td id="T_36428_row5_col4" class="data row5 col4" >0.914 +/- 0.022</td>
#       <td id="T_36428_row5_col5" class="data row5 col5" >0.942 +/- 0.005</td>
#       <td id="T_36428_row5_col6" class="data row5 col6" >0.912 +/- 0.015</td>
#     </tr>
#   </tbody>
# </table>
# ### AMLSim 201
# <style type="text/css">
# #T_2a9f0_row0_col2, #T_2a9f0_row1_col2, #T_2a9f0_row2_col2, #T_2a9f0_row3_col2, #T_2a9f0_row4_col3, #T_2a9f0_row5_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2a9f0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a9f0_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_2a9f0_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_2a9f0_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_2a9f0_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_2a9f0_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_2a9f0_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_2a9f0_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a9f0_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_2a9f0_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_2a9f0_row0_col0" class="data row0 col0" >0.723 +/- 0.036</td>
#       <td id="T_2a9f0_row0_col1" class="data row0 col1" >0.743 +/- 0.064</td>
#       <td id="T_2a9f0_row0_col2" class="data row0 col2" >0.817 +/- 0.038</td>
#       <td id="T_2a9f0_row0_col3" class="data row0 col3" >0.465 +/- 0.063</td>
#       <td id="T_2a9f0_row0_col4" class="data row0 col4" >0.745 +/- 0.042</td>
#       <td id="T_2a9f0_row0_col5" class="data row0 col5" >0.723 +/- 0.034</td>
#       <td id="T_2a9f0_row0_col6" class="data row0 col6" >0.741 +/- 0.042</td>
#     </tr>
#     <tr>
#       <th id="T_2a9f0_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_2a9f0_row1_col0" class="data row1 col0" >0.854 +/- 0.019</td>
#       <td id="T_2a9f0_row1_col1" class="data row1 col1" >0.866 +/- 0.033</td>
#       <td id="T_2a9f0_row1_col2" class="data row1 col2" >0.904 +/- 0.020</td>
#       <td id="T_2a9f0_row1_col3" class="data row1 col3" >0.706 +/- 0.039</td>
#       <td id="T_2a9f0_row1_col4" class="data row1 col4" >0.867 +/- 0.022</td>
#       <td id="T_2a9f0_row1_col5" class="data row1 col5" >0.854 +/- 0.018</td>
#       <td id="T_2a9f0_row1_col6" class="data row1 col6" >0.865 +/- 0.022</td>
#     </tr>
#     <tr>
#       <th id="T_2a9f0_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_2a9f0_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_2a9f0_row2_col0" class="data row2 col0" >0.673 +/- 0.062</td>
#       <td id="T_2a9f0_row2_col1" class="data row2 col1" >0.813 +/- 0.083</td>
#       <td id="T_2a9f0_row2_col2" class="data row2 col2" >0.916 +/- 0.024</td>
#       <td id="T_2a9f0_row2_col3" class="data row2 col3" >0.311 +/- 0.056</td>
#       <td id="T_2a9f0_row2_col4" class="data row2 col4" >0.777 +/- 0.063</td>
#       <td id="T_2a9f0_row2_col5" class="data row2 col5" >0.672 +/- 0.057</td>
#       <td id="T_2a9f0_row2_col6" class="data row2 col6" >0.814 +/- 0.069</td>
#     </tr>
#     <tr>
#       <th id="T_2a9f0_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_2a9f0_row3_col0" class="data row3 col0" >0.831 +/- 0.031</td>
#       <td id="T_2a9f0_row3_col1" class="data row3 col1" >0.899 +/- 0.043</td>
#       <td id="T_2a9f0_row3_col2" class="data row3 col2" >0.916 +/- 0.024</td>
#       <td id="T_2a9f0_row3_col3" class="data row3 col3" >0.654 +/- 0.028</td>
#       <td id="T_2a9f0_row3_col4" class="data row3 col4" >0.882 +/- 0.032</td>
#       <td id="T_2a9f0_row3_col5" class="data row3 col5" >0.831 +/- 0.029</td>
#       <td id="T_2a9f0_row3_col6" class="data row3 col6" >0.900 +/- 0.035</td>
#     </tr>
#     <tr>
#       <th id="T_2a9f0_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_2a9f0_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_2a9f0_row4_col0" class="data row4 col0" >0.782 +/- 0.020</td>
#       <td id="T_2a9f0_row4_col1" class="data row4 col1" >0.685 +/- 0.061</td>
#       <td id="T_2a9f0_row4_col2" class="data row4 col2" >0.794 +/- 0.075</td>
#       <td id="T_2a9f0_row4_col3" class="data row4 col3" >0.926 +/- 0.067</td>
#       <td id="T_2a9f0_row4_col4" class="data row4 col4" >0.717 +/- 0.059</td>
#       <td id="T_2a9f0_row4_col5" class="data row4 col5" >0.782 +/- 0.016</td>
#       <td id="T_2a9f0_row4_col6" class="data row4 col6" >0.681 +/- 0.041</td>
#     </tr>
#     <tr>
#       <th id="T_2a9f0_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_2a9f0_row5_col0" class="data row5 col0" >0.882 +/- 0.010</td>
#       <td id="T_2a9f0_row5_col1" class="data row5 col1" >0.839 +/- 0.032</td>
#       <td id="T_2a9f0_row5_col2" class="data row5 col2" >0.893 +/- 0.037</td>
#       <td id="T_2a9f0_row5_col3" class="data row5 col3" >0.914 +/- 0.031</td>
#       <td id="T_2a9f0_row5_col4" class="data row5 col4" >0.853 +/- 0.029</td>
#       <td id="T_2a9f0_row5_col5" class="data row5 col5" >0.882 +/- 0.008</td>
#       <td id="T_2a9f0_row5_col6" class="data row5 col6" >0.837 +/- 0.021</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Summarize raw scores
#
# Summaries of raw scores below are done without the use of the Bootstrap method.

# %%
scores_sorting = [f"amlsim_{num}_CI_SUMMARY" for num in [31, 51, 101, 201]]

# %%
all_raw_scores_df.groupby("dataset").agg(['mean', 'std']).loc[scores_sorting]
# Out:
#                       Macro Precision           Macro Recall            \
#                                  mean       std         mean       std
# dataset
# amlsim_31_CI_SUMMARY         0.964645  0.005507     0.967572  0.007059
# amlsim_51_CI_SUMMARY         0.941986  0.006247     0.950945  0.004803
# amlsim_101_CI_SUMMARY        0.943921  0.005747     0.907861  0.005438
# amlsim_201_CI_SUMMARY        0.916032  0.010571     0.892758  0.016147
#
#                        Macro F1           Ilicit Precision            \
#                            mean       std             mean       std
# dataset
# amlsim_31_CI_SUMMARY   0.966049  0.006153         0.964645  0.005507
# amlsim_51_CI_SUMMARY   0.946314  0.004273         0.941986  0.006247
# amlsim_101_CI_SUMMARY  0.924852  0.004004         0.943921  0.005747
# amlsim_201_CI_SUMMARY  0.903728  0.008714         0.916032  0.010571
#
#                       Ilicit Recall           Ilicit F1
#                                mean       std      mean       std
# dataset
# amlsim_31_CI_SUMMARY       0.963436  0.012977  0.956456  0.007986
# amlsim_51_CI_SUMMARY       0.928194  0.010999  0.915310  0.006657
# amlsim_101_CI_SUMMARY      0.825551  0.011222  0.864782  0.007226
# amlsim_201_CI_SUMMARY      0.793833  0.033084  0.817390  0.016664

# %% [markdown]
# ## Calculate boostrap CIs

# %%
dataset_bootstrap_scores = {}
metrics = [col for col in all_raw_scores_df.columns if col != 'dataset']
for dataset in all_raw_scores_df.dataset.unique():
    dataset_scores = all_raw_scores_df[all_raw_scores_df.dataset == dataset]
    for metric in metrics:
        boostrap_avg_ci, bootstrap_std_ci = model_metrics.get_confidence_intervals(dataset_scores[metric], n_repeats=config.n_repeats)
        dataset_bootstrap_scores[(dataset, metric)] = {
            "avg": boostrap_avg_ci,
            "std": bootstrap_std_ci
        }
dataset_bootstrap_scores_df = pd.DataFrame(dataset_bootstrap_scores).T

# %%
dataset_bootstrap_scores_df.round(3).loc[scores_sorting]
# Out:
#                                           avg    std
# amlsim_31_CI_SUMMARY  Macro Precision   0.965  0.012
#                       Macro Recall      0.968  0.016
#                       Macro F1          0.966  0.014
#                       Ilicit Precision  0.965  0.012
#                       Ilicit Recall     0.963  0.029
#                       Ilicit F1         0.956  0.018
# amlsim_51_CI_SUMMARY  Macro Precision   0.942  0.014
#                       Macro Recall      0.951  0.011
#                       Macro F1          0.946  0.010
#                       Ilicit Precision  0.942  0.014
#                       Ilicit Recall     0.928  0.025
#                       Ilicit F1         0.915  0.015
# amlsim_101_CI_SUMMARY Macro Precision   0.944  0.013
#                       Macro Recall      0.908  0.012
#                       Macro F1          0.925  0.009
#                       Ilicit Precision  0.944  0.013
#                       Ilicit Recall     0.826  0.025
#                       Ilicit F1         0.865  0.016
# amlsim_201_CI_SUMMARY Macro Precision   0.916  0.024
#                       Macro Recall      0.893  0.037
#                       Macro F1          0.904  0.020
#                       Ilicit Precision  0.916  0.024
#                       Ilicit Recall     0.794  0.075
#                       Ilicit F1         0.817  0.038

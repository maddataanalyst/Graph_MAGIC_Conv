# %% [markdown]
# # Intro
#
# This notebook is used to visualize and manipulate results of the study. It should be run after the `dvc repro` command was successfully executed.

# %% [markdown]
# # Load libs

# %%
import os
import pandas as pd
import yaml
from IPython.display import display, Markdown

import autoroot
import autorootcwd

# %%
import aml_magic.src.consts as cc
import aml_magic.src.models.metrics as model_metrics
import aml_magic.src.utils.configs as cfg
import aml_magic.src.stages.summarize_results as sumres

# %% [markdown]
# # Load data

# %% [markdown]
# ## Load config

# %%
config_yaml = yaml.safe_load(open(f"{cc.MAIN_PARAMS_FILE}.yaml", "r"))
config = cfg.ExperimentConfig(**config_yaml)

# %% [markdown]
# ## Load summary data

# %%
summary_data = pd.read_csv(cc.STUDY_COMPARISON_PATH / "scores_summary.csv")
summary_data.head(3)
# Out:
#       dataset     metric   scope        MAGIC+XGB          GCN+XGB  \
# 0  AMLSim 101         F1  Ilicit  0.870 +/- 0.033  0.814 +/- 0.032
# 1  AMLSim 101         F1   Macro  0.929 +/- 0.018  0.898 +/- 0.018
# 2  AMLSim 101  Precision  Ilicit  0.941 +/- 0.022  0.786 +/- 0.052
#
#               Nenn         Nenn+XGB          SkipGCN      SkipGCN+XGB  \
# 0  0.725 +/- 0.041  0.837 +/- 0.027  0.807 +/- 0.033  0.812 +/- 0.030
# 1  0.844 +/- 0.024  0.910 +/- 0.015  0.892 +/- 0.019  0.896 +/- 0.017
# 2  0.592 +/- 0.051  0.828 +/- 0.035  0.719 +/- 0.056  0.779 +/- 0.050
#
#                GCN
# 0  0.810 +/- 0.035
# 1  0.894 +/- 0.020
# 2  0.724 +/- 0.058

# %% [markdown]
# ## Load raw scores per dataset

# %%
all_raw_scores = []
for dataset in os.listdir(cc.STUDY_RESULTS_PATH):
    dataset_raw_scores = pd.read_csv(cc.STUDY_RESULTS_PATH / dataset / f"{dataset}_MAGIC+xgboost_raw.csv", index_col=0).drop(columns='model')
    dataset_raw_scores["dataset"] = dataset
    all_raw_scores.append(dataset_raw_scores)

all_raw_scores_df = pd.concat(all_raw_scores, ignore_index=True)

# %% [markdown]
# # Show results

# %% [markdown]
# ## Summaries

# %%
sorting_order = [f"AMLSim {num}" for num in [31, 51, 101, 201]]
summarized_datasets = summary_data.pivot_table(
    index=['dataset', 'metric', 'scope'],
    aggfunc='max'
)

for ds in sorting_order:
    display(Markdown(f"### {ds}"))
    display(summarized_datasets.loc[ds].style.highlight_max(color='lightgreen', axis=1) )
# Out:
# ### AMLSim 31
# <style type="text/css">
# #T_f1a55_row0_col2, #T_f1a55_row1_col2, #T_f1a55_row2_col2, #T_f1a55_row3_col1, #T_f1a55_row4_col2, #T_f1a55_row5_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f1a55">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1a55_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_f1a55_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_f1a55_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_f1a55_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_f1a55_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_f1a55_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_f1a55_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1a55_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_f1a55_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_f1a55_row0_col0" class="data row0 col0" >0.947 +/- 0.001</td>
#       <td id="T_f1a55_row0_col1" class="data row0 col1" >0.949 +/- 0.011</td>
#       <td id="T_f1a55_row0_col2" class="data row0 col2" >0.953 +/- 0.013</td>
#       <td id="T_f1a55_row0_col3" class="data row0 col3" >0.933 +/- 0.021</td>
#       <td id="T_f1a55_row0_col4" class="data row0 col4" >0.946 +/- 0.017</td>
#       <td id="T_f1a55_row0_col5" class="data row0 col5" >0.948 +/- 0.002</td>
#       <td id="T_f1a55_row0_col6" class="data row0 col6" >0.948 +/- 0.010</td>
#     </tr>
#     <tr>
#       <th id="T_f1a55_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_f1a55_row1_col0" class="data row1 col0" >0.962 +/- 0.001</td>
#       <td id="T_f1a55_row1_col1" class="data row1 col1" >0.964 +/- 0.008</td>
#       <td id="T_f1a55_row1_col2" class="data row1 col2" >0.966 +/- 0.010</td>
#       <td id="T_f1a55_row1_col3" class="data row1 col3" >0.951 +/- 0.015</td>
#       <td id="T_f1a55_row1_col4" class="data row1 col4" >0.961 +/- 0.013</td>
#       <td id="T_f1a55_row1_col5" class="data row1 col5" >0.962 +/- 0.001</td>
#       <td id="T_f1a55_row1_col6" class="data row1 col6" >0.963 +/- 0.007</td>
#     </tr>
#     <tr>
#       <th id="T_f1a55_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_f1a55_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_f1a55_row2_col0" class="data row2 col0" >0.913 +/- 0.002</td>
#       <td id="T_f1a55_row2_col1" class="data row2 col1" >0.928 +/- 0.010</td>
#       <td id="T_f1a55_row2_col2" class="data row2 col2" >0.957 +/- 0.010</td>
#       <td id="T_f1a55_row2_col3" class="data row2 col3" >0.894 +/- 0.023</td>
#       <td id="T_f1a55_row2_col4" class="data row2 col4" >0.918 +/- 0.024</td>
#       <td id="T_f1a55_row2_col5" class="data row2 col5" >0.913 +/- 0.003</td>
#       <td id="T_f1a55_row2_col6" class="data row2 col6" >0.927 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_f1a55_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_f1a55_row3_col0" class="data row3 col0" >0.953 +/- 0.001</td>
#       <td id="T_f1a55_row3_col1" class="data row3 col1" >0.958 +/- 0.006</td>
#       <td id="T_f1a55_row3_col2" class="data row3 col2" >0.957 +/- 0.010</td>
#       <td id="T_f1a55_row3_col3" class="data row3 col3" >0.941 +/- 0.015</td>
#       <td id="T_f1a55_row3_col4" class="data row3 col4" >0.954 +/- 0.014</td>
#       <td id="T_f1a55_row3_col5" class="data row3 col5" >0.953 +/- 0.002</td>
#       <td id="T_f1a55_row3_col6" class="data row3 col6" >0.957 +/- 0.006</td>
#     </tr>
#     <tr>
#       <th id="T_f1a55_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_f1a55_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_f1a55_row4_col0" class="data row4 col0" >0.984 +/- 0.000</td>
#       <td id="T_f1a55_row4_col1" class="data row4 col1" >0.971 +/- 0.020</td>
#       <td id="T_f1a55_row4_col2" class="data row4 col2" >0.988 +/- 0.018</td>
#       <td id="T_f1a55_row4_col3" class="data row4 col3" >0.975 +/- 0.030</td>
#       <td id="T_f1a55_row4_col4" class="data row4 col4" >0.976 +/- 0.021</td>
#       <td id="T_f1a55_row4_col5" class="data row4 col5" >0.984 +/- 0.000</td>
#       <td id="T_f1a55_row4_col6" class="data row4 col6" >0.970 +/- 0.019</td>
#     </tr>
#     <tr>
#       <th id="T_f1a55_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_f1a55_row5_col0" class="data row5 col0" >0.973 +/- 0.001</td>
#       <td id="T_f1a55_row5_col1" class="data row5 col1" >0.970 +/- 0.010</td>
#       <td id="T_f1a55_row5_col2" class="data row5 col2" >0.976 +/- 0.010</td>
#       <td id="T_f1a55_row5_col3" class="data row5 col3" >0.963 +/- 0.017</td>
#       <td id="T_f1a55_row5_col4" class="data row5 col4" >0.970 +/- 0.012</td>
#       <td id="T_f1a55_row5_col5" class="data row5 col5" >0.973 +/- 0.001</td>
#       <td id="T_f1a55_row5_col6" class="data row5 col6" >0.969 +/- 0.009</td>
#     </tr>
#   </tbody>
# </table>
# ### AMLSim 51
# <style type="text/css">
# #T_c313b_row0_col2, #T_c313b_row1_col2, #T_c313b_row2_col2, #T_c313b_row3_col2, #T_c313b_row4_col5, #T_c313b_row5_col0, #T_c313b_row5_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c313b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c313b_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_c313b_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_c313b_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_c313b_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_c313b_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_c313b_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_c313b_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c313b_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_c313b_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_c313b_row0_col0" class="data row0 col0" >0.901 +/- 0.011</td>
#       <td id="T_c313b_row0_col1" class="data row0 col1" >0.905 +/- 0.019</td>
#       <td id="T_c313b_row0_col2" class="data row0 col2" >0.908 +/- 0.030</td>
#       <td id="T_c313b_row0_col3" class="data row0 col3" >0.872 +/- 0.023</td>
#       <td id="T_c313b_row0_col4" class="data row0 col4" >0.895 +/- 0.025</td>
#       <td id="T_c313b_row0_col5" class="data row0 col5" >0.902 +/- 0.012</td>
#       <td id="T_c313b_row0_col6" class="data row0 col6" >0.904 +/- 0.017</td>
#     </tr>
#     <tr>
#       <th id="T_c313b_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_c313b_row1_col0" class="data row1 col0" >0.939 +/- 0.007</td>
#       <td id="T_c313b_row1_col1" class="data row1 col1" >0.941 +/- 0.012</td>
#       <td id="T_c313b_row1_col2" class="data row1 col2" >0.944 +/- 0.018</td>
#       <td id="T_c313b_row1_col3" class="data row1 col3" >0.921 +/- 0.014</td>
#       <td id="T_c313b_row1_col4" class="data row1 col4" >0.936 +/- 0.016</td>
#       <td id="T_c313b_row1_col5" class="data row1 col5" >0.939 +/- 0.008</td>
#       <td id="T_c313b_row1_col6" class="data row1 col6" >0.941 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_c313b_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_c313b_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_c313b_row2_col0" class="data row2 col0" >0.840 +/- 0.021</td>
#       <td id="T_c313b_row2_col1" class="data row2 col1" >0.878 +/- 0.024</td>
#       <td id="T_c313b_row2_col2" class="data row2 col2" >0.943 +/- 0.015</td>
#       <td id="T_c313b_row2_col3" class="data row2 col3" >0.823 +/- 0.031</td>
#       <td id="T_c313b_row2_col4" class="data row2 col4" >0.873 +/- 0.043</td>
#       <td id="T_c313b_row2_col5" class="data row2 col5" >0.840 +/- 0.022</td>
#       <td id="T_c313b_row2_col6" class="data row2 col6" >0.876 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_c313b_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_c313b_row3_col0" class="data row3 col0" >0.917 +/- 0.010</td>
#       <td id="T_c313b_row3_col1" class="data row3 col1" >0.931 +/- 0.013</td>
#       <td id="T_c313b_row3_col2" class="data row3 col2" >0.943 +/- 0.015</td>
#       <td id="T_c313b_row3_col3" class="data row3 col3" >0.903 +/- 0.016</td>
#       <td id="T_c313b_row3_col4" class="data row3 col4" >0.928 +/- 0.022</td>
#       <td id="T_c313b_row3_col5" class="data row3 col5" >0.917 +/- 0.011</td>
#       <td id="T_c313b_row3_col6" class="data row3 col6" >0.931 +/- 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_c313b_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_c313b_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_c313b_row4_col0" class="data row4 col0" >0.973 +/- 0.004</td>
#       <td id="T_c313b_row4_col1" class="data row4 col1" >0.933 +/- 0.029</td>
#       <td id="T_c313b_row4_col2" class="data row4 col2" >0.911 +/- 0.046</td>
#       <td id="T_c313b_row4_col3" class="data row4 col3" >0.927 +/- 0.032</td>
#       <td id="T_c313b_row4_col4" class="data row4 col4" >0.919 +/- 0.028</td>
#       <td id="T_c313b_row4_col5" class="data row4 col5" >0.974 +/- 0.003</td>
#       <td id="T_c313b_row4_col6" class="data row4 col6" >0.934 +/- 0.029</td>
#     </tr>
#     <tr>
#       <th id="T_c313b_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_c313b_row5_col0" class="data row5 col0" >0.966 +/- 0.003</td>
#       <td id="T_c313b_row5_col1" class="data row5 col1" >0.952 +/- 0.015</td>
#       <td id="T_c313b_row5_col2" class="data row5 col2" >0.945 +/- 0.024</td>
#       <td id="T_c313b_row5_col3" class="data row5 col3" >0.941 +/- 0.016</td>
#       <td id="T_c313b_row5_col4" class="data row5 col4" >0.945 +/- 0.014</td>
#       <td id="T_c313b_row5_col5" class="data row5 col5" >0.966 +/- 0.003</td>
#       <td id="T_c313b_row5_col6" class="data row5 col6" >0.952 +/- 0.014</td>
#     </tr>
#   </tbody>
# </table>
# ### AMLSim 101
# <style type="text/css">
# #T_ce2b1_row0_col2, #T_ce2b1_row1_col2, #T_ce2b1_row2_col2, #T_ce2b1_row3_col2, #T_ce2b1_row4_col3, #T_ce2b1_row5_col0, #T_ce2b1_row5_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ce2b1">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce2b1_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_ce2b1_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_ce2b1_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_ce2b1_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_ce2b1_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_ce2b1_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_ce2b1_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce2b1_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_ce2b1_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_ce2b1_row0_col0" class="data row0 col0" >0.810 +/- 0.035</td>
#       <td id="T_ce2b1_row0_col1" class="data row0 col1" >0.814 +/- 0.032</td>
#       <td id="T_ce2b1_row0_col2" class="data row0 col2" >0.870 +/- 0.033</td>
#       <td id="T_ce2b1_row0_col3" class="data row0 col3" >0.725 +/- 0.041</td>
#       <td id="T_ce2b1_row0_col4" class="data row0 col4" >0.837 +/- 0.027</td>
#       <td id="T_ce2b1_row0_col5" class="data row0 col5" >0.807 +/- 0.033</td>
#       <td id="T_ce2b1_row0_col6" class="data row0 col6" >0.812 +/- 0.030</td>
#     </tr>
#     <tr>
#       <th id="T_ce2b1_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_ce2b1_row1_col0" class="data row1 col0" >0.894 +/- 0.020</td>
#       <td id="T_ce2b1_row1_col1" class="data row1 col1" >0.898 +/- 0.018</td>
#       <td id="T_ce2b1_row1_col2" class="data row1 col2" >0.929 +/- 0.018</td>
#       <td id="T_ce2b1_row1_col3" class="data row1 col3" >0.844 +/- 0.024</td>
#       <td id="T_ce2b1_row1_col4" class="data row1 col4" >0.910 +/- 0.015</td>
#       <td id="T_ce2b1_row1_col5" class="data row1 col5" >0.892 +/- 0.019</td>
#       <td id="T_ce2b1_row1_col6" class="data row1 col6" >0.896 +/- 0.017</td>
#     </tr>
#     <tr>
#       <th id="T_ce2b1_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_ce2b1_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_ce2b1_row2_col0" class="data row2 col0" >0.724 +/- 0.058</td>
#       <td id="T_ce2b1_row2_col1" class="data row2 col1" >0.786 +/- 0.052</td>
#       <td id="T_ce2b1_row2_col2" class="data row2 col2" >0.941 +/- 0.022</td>
#       <td id="T_ce2b1_row2_col3" class="data row2 col3" >0.592 +/- 0.051</td>
#       <td id="T_ce2b1_row2_col4" class="data row2 col4" >0.828 +/- 0.035</td>
#       <td id="T_ce2b1_row2_col5" class="data row2 col5" >0.719 +/- 0.056</td>
#       <td id="T_ce2b1_row2_col6" class="data row2 col6" >0.779 +/- 0.050</td>
#     </tr>
#     <tr>
#       <th id="T_ce2b1_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_ce2b1_row3_col0" class="data row3 col0" >0.858 +/- 0.029</td>
#       <td id="T_ce2b1_row3_col1" class="data row3 col1" >0.885 +/- 0.026</td>
#       <td id="T_ce2b1_row3_col2" class="data row3 col2" >0.941 +/- 0.022</td>
#       <td id="T_ce2b1_row3_col3" class="data row3 col3" >0.793 +/- 0.026</td>
#       <td id="T_ce2b1_row3_col4" class="data row3 col4" >0.906 +/- 0.018</td>
#       <td id="T_ce2b1_row3_col5" class="data row3 col5" >0.855 +/- 0.028</td>
#       <td id="T_ce2b1_row3_col6" class="data row3 col6" >0.882 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_ce2b1_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_ce2b1_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_ce2b1_row4_col0" class="data row4 col0" >0.920 +/- 0.009</td>
#       <td id="T_ce2b1_row4_col1" class="data row4 col1" >0.846 +/- 0.040</td>
#       <td id="T_ce2b1_row4_col2" class="data row4 col2" >0.845 +/- 0.046</td>
#       <td id="T_ce2b1_row4_col3" class="data row4 col3" >0.936 +/- 0.032</td>
#       <td id="T_ce2b1_row4_col4" class="data row4 col4" >0.847 +/- 0.045</td>
#       <td id="T_ce2b1_row4_col5" class="data row4 col5" >0.920 +/- 0.010</td>
#       <td id="T_ce2b1_row4_col6" class="data row4 col6" >0.847 +/- 0.032</td>
#     </tr>
#     <tr>
#       <th id="T_ce2b1_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_ce2b1_row5_col0" class="data row5 col0" >0.942 +/- 0.005</td>
#       <td id="T_ce2b1_row5_col1" class="data row5 col1" >0.911 +/- 0.020</td>
#       <td id="T_ce2b1_row5_col2" class="data row5 col2" >0.918 +/- 0.023</td>
#       <td id="T_ce2b1_row5_col3" class="data row5 col3" >0.936 +/- 0.017</td>
#       <td id="T_ce2b1_row5_col4" class="data row5 col4" >0.914 +/- 0.022</td>
#       <td id="T_ce2b1_row5_col5" class="data row5 col5" >0.942 +/- 0.005</td>
#       <td id="T_ce2b1_row5_col6" class="data row5 col6" >0.912 +/- 0.015</td>
#     </tr>
#   </tbody>
# </table>
# ### AMLSim 201
# <style type="text/css">
# #T_0069d_row0_col2, #T_0069d_row1_col2, #T_0069d_row2_col2, #T_0069d_row3_col2, #T_0069d_row4_col3, #T_0069d_row5_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0069d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0069d_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_0069d_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_0069d_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_0069d_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_0069d_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_0069d_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_0069d_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >metric</th>
#       <th class="index_name level1" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0069d_level0_row0" class="row_heading level0 row0" rowspan="2">F1</th>
#       <th id="T_0069d_level1_row0" class="row_heading level1 row0" >Ilicit</th>
#       <td id="T_0069d_row0_col0" class="data row0 col0" >0.723 +/- 0.036</td>
#       <td id="T_0069d_row0_col1" class="data row0 col1" >0.743 +/- 0.064</td>
#       <td id="T_0069d_row0_col2" class="data row0 col2" >0.816 +/- 0.031</td>
#       <td id="T_0069d_row0_col3" class="data row0 col3" >0.465 +/- 0.063</td>
#       <td id="T_0069d_row0_col4" class="data row0 col4" >0.745 +/- 0.042</td>
#       <td id="T_0069d_row0_col5" class="data row0 col5" >0.723 +/- 0.034</td>
#       <td id="T_0069d_row0_col6" class="data row0 col6" >0.741 +/- 0.042</td>
#     </tr>
#     <tr>
#       <th id="T_0069d_level1_row1" class="row_heading level1 row1" >Macro</th>
#       <td id="T_0069d_row1_col0" class="data row1 col0" >0.854 +/- 0.019</td>
#       <td id="T_0069d_row1_col1" class="data row1 col1" >0.866 +/- 0.033</td>
#       <td id="T_0069d_row1_col2" class="data row1 col2" >0.904 +/- 0.016</td>
#       <td id="T_0069d_row1_col3" class="data row1 col3" >0.706 +/- 0.039</td>
#       <td id="T_0069d_row1_col4" class="data row1 col4" >0.867 +/- 0.022</td>
#       <td id="T_0069d_row1_col5" class="data row1 col5" >0.854 +/- 0.018</td>
#       <td id="T_0069d_row1_col6" class="data row1 col6" >0.865 +/- 0.022</td>
#     </tr>
#     <tr>
#       <th id="T_0069d_level0_row2" class="row_heading level0 row2" rowspan="2">Precision</th>
#       <th id="T_0069d_level1_row2" class="row_heading level1 row2" >Ilicit</th>
#       <td id="T_0069d_row2_col0" class="data row2 col0" >0.673 +/- 0.062</td>
#       <td id="T_0069d_row2_col1" class="data row2 col1" >0.813 +/- 0.083</td>
#       <td id="T_0069d_row2_col2" class="data row2 col2" >0.907 +/- 0.021</td>
#       <td id="T_0069d_row2_col3" class="data row2 col3" >0.311 +/- 0.056</td>
#       <td id="T_0069d_row2_col4" class="data row2 col4" >0.777 +/- 0.063</td>
#       <td id="T_0069d_row2_col5" class="data row2 col5" >0.672 +/- 0.057</td>
#       <td id="T_0069d_row2_col6" class="data row2 col6" >0.814 +/- 0.069</td>
#     </tr>
#     <tr>
#       <th id="T_0069d_level1_row3" class="row_heading level1 row3" >Macro</th>
#       <td id="T_0069d_row3_col0" class="data row3 col0" >0.831 +/- 0.031</td>
#       <td id="T_0069d_row3_col1" class="data row3 col1" >0.899 +/- 0.043</td>
#       <td id="T_0069d_row3_col2" class="data row3 col2" >0.907 +/- 0.021</td>
#       <td id="T_0069d_row3_col3" class="data row3 col3" >0.654 +/- 0.028</td>
#       <td id="T_0069d_row3_col4" class="data row3 col4" >0.882 +/- 0.032</td>
#       <td id="T_0069d_row3_col5" class="data row3 col5" >0.831 +/- 0.029</td>
#       <td id="T_0069d_row3_col6" class="data row3 col6" >0.900 +/- 0.035</td>
#     </tr>
#     <tr>
#       <th id="T_0069d_level0_row4" class="row_heading level0 row4" rowspan="2">Recall</th>
#       <th id="T_0069d_level1_row4" class="row_heading level1 row4" >Ilicit</th>
#       <td id="T_0069d_row4_col0" class="data row4 col0" >0.782 +/- 0.020</td>
#       <td id="T_0069d_row4_col1" class="data row4 col1" >0.685 +/- 0.061</td>
#       <td id="T_0069d_row4_col2" class="data row4 col2" >0.810 +/- 0.053</td>
#       <td id="T_0069d_row4_col3" class="data row4 col3" >0.926 +/- 0.067</td>
#       <td id="T_0069d_row4_col4" class="data row4 col4" >0.717 +/- 0.059</td>
#       <td id="T_0069d_row4_col5" class="data row4 col5" >0.782 +/- 0.016</td>
#       <td id="T_0069d_row4_col6" class="data row4 col6" >0.681 +/- 0.041</td>
#     </tr>
#     <tr>
#       <th id="T_0069d_level1_row5" class="row_heading level1 row5" >Macro</th>
#       <td id="T_0069d_row5_col0" class="data row5 col0" >0.882 +/- 0.010</td>
#       <td id="T_0069d_row5_col1" class="data row5 col1" >0.839 +/- 0.032</td>
#       <td id="T_0069d_row5_col2" class="data row5 col2" >0.901 +/- 0.026</td>
#       <td id="T_0069d_row5_col3" class="data row5 col3" >0.914 +/- 0.031</td>
#       <td id="T_0069d_row5_col4" class="data row5 col4" >0.853 +/- 0.029</td>
#       <td id="T_0069d_row5_col5" class="data row5 col5" >0.882 +/- 0.008</td>
#       <td id="T_0069d_row5_col6" class="data row5 col6" >0.837 +/- 0.021</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Summarize raw scores
#
# Summaries of raw scores below are done without the use of the Bootstrap method.

# %%
scores_sorting = [f"amlsim_{num}_CI_SUMMARY" for num in [31, 51, 101, 201]]

# %%
all_raw_scores_df.groupby("dataset").agg(['mean', 'std']).loc[scores_sorting]
# Out:
#                       Macro Precision           Macro Recall            \
#                                  mean       std         mean       std
# dataset
# amlsim_31_CI_SUMMARY         0.957170  0.004426     0.975874  0.004543
# amlsim_51_CI_SUMMARY         0.943014  0.006805     0.945181  0.010455
# amlsim_101_CI_SUMMARY        0.940731  0.009550     0.917682  0.010177
# amlsim_201_CI_SUMMARY        0.906885  0.009173     0.900835  0.011441
#
#                        Macro F1           Ilicit Precision            \
#                            mean       std             mean       std
# dataset
# amlsim_31_CI_SUMMARY   0.965763  0.004306         0.957170  0.004426
# amlsim_51_CI_SUMMARY   0.944035  0.007895         0.943014  0.006805
# amlsim_101_CI_SUMMARY  0.928728  0.007971         0.940731  0.009550
# amlsim_201_CI_SUMMARY  0.903690  0.007046         0.906885  0.009173
#
#                       Ilicit Recall           Ilicit F1
#                                mean       std      mean       std
# dataset
# amlsim_31_CI_SUMMARY       0.988235  0.007892  0.952579  0.005956
# amlsim_51_CI_SUMMARY       0.911230  0.020511  0.908246  0.013087
# amlsim_101_CI_SUMMARY      0.844920  0.020324  0.869772  0.014600
# amlsim_201_CI_SUMMARY      0.809626  0.023269  0.815672  0.013522

# %% [markdown]
# ## Calculate boostrap CIs

# %%
dataset_bootstrap_scores = {}
metrics = [col for col in all_raw_scores_df.columns if col != 'dataset']
for dataset in all_raw_scores_df.dataset.unique():
    dataset_scores = all_raw_scores_df[all_raw_scores_df.dataset == dataset]
    for metric in metrics:
        boostrap_avg_ci, bootstrap_std_ci = model_metrics.get_confidence_intervals(dataset_scores[metric], n_repeats=config.n_repeats)
        dataset_bootstrap_scores[(dataset, metric)] = {
            "avg": boostrap_avg_ci,
            "std": bootstrap_std_ci
        }
dataset_bootstrap_scores_df = pd.DataFrame(dataset_bootstrap_scores).T

# %%
dataset_bootstrap_scores_df.round(3).loc[scores_sorting]
# Out:
#                                           avg    std
# amlsim_31_CI_SUMMARY  Macro Precision   0.957  0.010
#                       Macro Recall      0.976  0.010
#                       Macro F1          0.966  0.010
#                       Ilicit Precision  0.957  0.010
#                       Ilicit Recall     0.988  0.018
#                       Ilicit F1         0.953  0.013
# amlsim_51_CI_SUMMARY  Macro Precision   0.943  0.015
#                       Macro Recall      0.945  0.024
#                       Macro F1          0.944  0.018
#                       Ilicit Precision  0.943  0.015
#                       Ilicit Recall     0.911  0.046
#                       Ilicit F1         0.908  0.030
# amlsim_101_CI_SUMMARY Macro Precision   0.941  0.022
#                       Macro Recall      0.918  0.023
#                       Macro F1          0.929  0.018
#                       Ilicit Precision  0.941  0.022
#                       Ilicit Recall     0.845  0.046
#                       Ilicit F1         0.870  0.033
# amlsim_201_CI_SUMMARY Macro Precision   0.907  0.021
#                       Macro Recall      0.901  0.026
#                       Macro F1          0.904  0.016
#                       Ilicit Precision  0.907  0.021
#                       Ilicit Recall     0.810  0.053
#                       Ilicit F1         0.816  0.031

# %% [markdown]
# # Intro
#
# This notebook is used to visualize and manipulate results of the study. It should be run after the `dvc repro` command was successfully executed.

# %% [markdown]
# # Load libs

# %%
import os
import pandas as pd
import yaml

import autoroot
import autorootcwd

# %%
import aml_magic.src.consts as cc
import aml_magic.src.models.metrics as model_metrics
import aml_magic.src.utils.configs as cfg
# Out:
# /home/filip/miniconda3/envs/aml_magic/lib/python3.11/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_architectures" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %% [markdown]
# # Load data

# %% [markdown]
# ## Load config

# %%
config_yaml = yaml.safe_load(open(f"{cc.MAIN_PARAMS_FILE}.yaml", "r"))
config = cfg.ExperimentConfig(**config_yaml)

# %% [markdown]
# ## Load summary data

# %%
summary_data = pd.read_csv(cc.STUDY_COMPARISON_PATH / "scores_summary.csv")
summary_data.head(3)
# Out:
#       dataset     metric   scope        MAGIC+XGB              GCN  \
# 0  AMLSim 101         F1  Ilicit  0.866 +/- 0.009  0.810 +/- 0.035
# 1  AMLSim 101         F1   Macro  0.926 +/- 0.005  0.894 +/- 0.020
# 2  AMLSim 101  Precision  Ilicit  0.930 +/- 0.013  0.724 +/- 0.058
#
#            SkipGCN          GCN+XGB         Nenn+XGB             Nenn  \
# 0  0.807 +/- 0.033  0.814 +/- 0.032  0.837 +/- 0.027  0.725 +/- 0.041
# 1  0.892 +/- 0.019  0.898 +/- 0.018  0.910 +/- 0.015  0.844 +/- 0.024
# 2  0.719 +/- 0.056  0.786 +/- 0.052  0.828 +/- 0.035  0.592 +/- 0.051
#
#        SkipGCN+XGB
# 0  0.812 +/- 0.030
# 1  0.896 +/- 0.017
# 2  0.779 +/- 0.050

# %% [markdown]
# ## Load raw scores per dataset

# %%
all_raw_scores = []
for dataset in os.listdir(cc.STUDY_RESULTS_PATH):
    dataset_raw_scores = pd.read_csv(cc.STUDY_RESULTS_PATH / dataset / f"{dataset}_MAGIC+xgboost_raw.csv", index_col=0).drop(columns='model')
    dataset_raw_scores["dataset"] = dataset
    all_raw_scores.append(dataset_raw_scores)

all_raw_scores_df = pd.concat(all_raw_scores, ignore_index=True)

# %% [markdown]
# # Show results

# %% [markdown]
# ## Summaries

# %%
summary_data.pivot_table(
    index=['dataset', 'metric', 'scope'],
    aggfunc='max'
).sort_index(level=0, ascending=False).style.highlight_max(color='lightgreen', axis=1)
# Out:
# <style type="text/css">
# #T_7f858_row0_col0, #T_7f858_row0_col5, #T_7f858_row1_col5, #T_7f858_row2_col2, #T_7f858_row3_col2, #T_7f858_row4_col2, #T_7f858_row5_col2, #T_7f858_row6_col2, #T_7f858_row7_col2, #T_7f858_row8_col1, #T_7f858_row9_col2, #T_7f858_row10_col1, #T_7f858_row11_col2, #T_7f858_row12_col2, #T_7f858_row13_col3, #T_7f858_row14_col2, #T_7f858_row15_col2, #T_7f858_row16_col2, #T_7f858_row17_col2, #T_7f858_row18_col0, #T_7f858_row18_col5, #T_7f858_row19_col3, #T_7f858_row20_col2, #T_7f858_row21_col2, #T_7f858_row22_col2, #T_7f858_row23_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7f858">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f858_level0_col0" class="col_heading level0 col0" >GCN</th>
#       <th id="T_7f858_level0_col1" class="col_heading level0 col1" >GCN+XGB</th>
#       <th id="T_7f858_level0_col2" class="col_heading level0 col2" >MAGIC+XGB</th>
#       <th id="T_7f858_level0_col3" class="col_heading level0 col3" >Nenn</th>
#       <th id="T_7f858_level0_col4" class="col_heading level0 col4" >Nenn+XGB</th>
#       <th id="T_7f858_level0_col5" class="col_heading level0 col5" >SkipGCN</th>
#       <th id="T_7f858_level0_col6" class="col_heading level0 col6" >SkipGCN+XGB</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >metric</th>
#       <th class="index_name level2" >scope</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f858_level0_row0" class="row_heading level0 row0" rowspan="6">AMLSim 51</th>
#       <th id="T_7f858_level1_row0" class="row_heading level1 row0" rowspan="2">Recall</th>
#       <th id="T_7f858_level2_row0" class="row_heading level2 row0" >Macro</th>
#       <td id="T_7f858_row0_col0" class="data row0 col0" >0.966 +/- 0.003</td>
#       <td id="T_7f858_row0_col1" class="data row0 col1" >0.952 +/- 0.015</td>
#       <td id="T_7f858_row0_col2" class="data row0 col2" >0.957 +/- 0.014</td>
#       <td id="T_7f858_row0_col3" class="data row0 col3" >0.941 +/- 0.016</td>
#       <td id="T_7f858_row0_col4" class="data row0 col4" >0.945 +/- 0.014</td>
#       <td id="T_7f858_row0_col5" class="data row0 col5" >0.966 +/- 0.003</td>
#       <td id="T_7f858_row0_col6" class="data row0 col6" >0.952 +/- 0.014</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level2_row1" class="row_heading level2 row1" >Ilicit</th>
#       <td id="T_7f858_row1_col0" class="data row1 col0" >0.973 +/- 0.004</td>
#       <td id="T_7f858_row1_col1" class="data row1 col1" >0.933 +/- 0.029</td>
#       <td id="T_7f858_row1_col2" class="data row1 col2" >0.943 +/- 0.033</td>
#       <td id="T_7f858_row1_col3" class="data row1 col3" >0.927 +/- 0.032</td>
#       <td id="T_7f858_row1_col4" class="data row1 col4" >0.919 +/- 0.028</td>
#       <td id="T_7f858_row1_col5" class="data row1 col5" >0.974 +/- 0.003</td>
#       <td id="T_7f858_row1_col6" class="data row1 col6" >0.934 +/- 0.029</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level1_row2" class="row_heading level1 row2" rowspan="2">Precision</th>
#       <th id="T_7f858_level2_row2" class="row_heading level2 row2" >Macro</th>
#       <td id="T_7f858_row2_col0" class="data row2 col0" >0.917 +/- 0.010</td>
#       <td id="T_7f858_row2_col1" class="data row2 col1" >0.931 +/- 0.013</td>
#       <td id="T_7f858_row2_col2" class="data row2 col2" >0.936 +/- 0.013</td>
#       <td id="T_7f858_row2_col3" class="data row2 col3" >0.903 +/- 0.016</td>
#       <td id="T_7f858_row2_col4" class="data row2 col4" >0.928 +/- 0.022</td>
#       <td id="T_7f858_row2_col5" class="data row2 col5" >0.917 +/- 0.011</td>
#       <td id="T_7f858_row2_col6" class="data row2 col6" >0.931 +/- 0.012</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level2_row3" class="row_heading level2 row3" >Ilicit</th>
#       <td id="T_7f858_row3_col0" class="data row3 col0" >0.840 +/- 0.021</td>
#       <td id="T_7f858_row3_col1" class="data row3 col1" >0.878 +/- 0.024</td>
#       <td id="T_7f858_row3_col2" class="data row3 col2" >0.936 +/- 0.013</td>
#       <td id="T_7f858_row3_col3" class="data row3 col3" >0.823 +/- 0.031</td>
#       <td id="T_7f858_row3_col4" class="data row3 col4" >0.873 +/- 0.043</td>
#       <td id="T_7f858_row3_col5" class="data row3 col5" >0.840 +/- 0.022</td>
#       <td id="T_7f858_row3_col6" class="data row3 col6" >0.876 +/- 0.025</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level1_row4" class="row_heading level1 row4" rowspan="2">F1</th>
#       <th id="T_7f858_level2_row4" class="row_heading level2 row4" >Macro</th>
#       <td id="T_7f858_row4_col0" class="data row4 col0" >0.939 +/- 0.007</td>
#       <td id="T_7f858_row4_col1" class="data row4 col1" >0.941 +/- 0.012</td>
#       <td id="T_7f858_row4_col2" class="data row4 col2" >0.946 +/- 0.009</td>
#       <td id="T_7f858_row4_col3" class="data row4 col3" >0.921 +/- 0.014</td>
#       <td id="T_7f858_row4_col4" class="data row4 col4" >0.936 +/- 0.016</td>
#       <td id="T_7f858_row4_col5" class="data row4 col5" >0.939 +/- 0.008</td>
#       <td id="T_7f858_row4_col6" class="data row4 col6" >0.941 +/- 0.011</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level2_row5" class="row_heading level2 row5" >Ilicit</th>
#       <td id="T_7f858_row5_col0" class="data row5 col0" >0.901 +/- 0.011</td>
#       <td id="T_7f858_row5_col1" class="data row5 col1" >0.905 +/- 0.019</td>
#       <td id="T_7f858_row5_col2" class="data row5 col2" >0.914 +/- 0.014</td>
#       <td id="T_7f858_row5_col3" class="data row5 col3" >0.872 +/- 0.023</td>
#       <td id="T_7f858_row5_col4" class="data row5 col4" >0.895 +/- 0.025</td>
#       <td id="T_7f858_row5_col5" class="data row5 col5" >0.902 +/- 0.012</td>
#       <td id="T_7f858_row5_col6" class="data row5 col6" >0.904 +/- 0.017</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level0_row6" class="row_heading level0 row6" rowspan="6">AMLSim 31</th>
#       <th id="T_7f858_level1_row6" class="row_heading level1 row6" rowspan="2">Recall</th>
#       <th id="T_7f858_level2_row6" class="row_heading level2 row6" >Macro</th>
#       <td id="T_7f858_row6_col0" class="data row6 col0" >0.973 +/- 0.001</td>
#       <td id="T_7f858_row6_col1" class="data row6 col1" >0.970 +/- 0.010</td>
#       <td id="T_7f858_row6_col2" class="data row6 col2" >0.973 +/- 0.007</td>
#       <td id="T_7f858_row6_col3" class="data row6 col3" >0.963 +/- 0.017</td>
#       <td id="T_7f858_row6_col4" class="data row6 col4" >0.970 +/- 0.012</td>
#       <td id="T_7f858_row6_col5" class="data row6 col5" >0.973 +/- 0.001</td>
#       <td id="T_7f858_row6_col6" class="data row6 col6" >0.969 +/- 0.009</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level2_row7" class="row_heading level2 row7" >Ilicit</th>
#       <td id="T_7f858_row7_col0" class="data row7 col0" >0.984 +/- 0.000</td>
#       <td id="T_7f858_row7_col1" class="data row7 col1" >0.971 +/- 0.020</td>
#       <td id="T_7f858_row7_col2" class="data row7 col2" >0.987 +/- 0.011</td>
#       <td id="T_7f858_row7_col3" class="data row7 col3" >0.975 +/- 0.030</td>
#       <td id="T_7f858_row7_col4" class="data row7 col4" >0.976 +/- 0.021</td>
#       <td id="T_7f858_row7_col5" class="data row7 col5" >0.984 +/- 0.000</td>
#       <td id="T_7f858_row7_col6" class="data row7 col6" >0.970 +/- 0.019</td>
#     </tr>
#     <tr>
#       <th id="T_7f858_level1_row8" class="row_heading level1 row8" rowspan="2">Precision</th>
#       <th id="T_7f858_level2_row8" class="row_heading level2 row8" >Macro</th>
#       <td id="T_7f858_row8_col0" class="data row8 col0" >0.953 +/- 0.001</td>
#       <td id="T_7f858_row8_col1" class="data row8 col1" >0.958 +/- 0.006</td>
#       <td id="T_7f858_row8_col2" class="data row8 col2" >0.955 +/- 0.011</td>
#       <td id="T_7f858_row8_col3" class="data row8 col3" >0

# %% [markdown]
# ## Summarize raw scores
#
# Summaries of raw scores below are done without the use of the Bootstrap method.

# %%
all_raw_scores_df.groupby("dataset").agg(['mean', 'std'])
# Out:
#            Macro Precision           Macro Recall            Macro F1  \
#                       mean       std         mean       std      mean
# dataset
# amlsim_101        0.930039  0.005641     0.923016  0.008222  0.926366
# amlsim_201        0.918473  0.010095     0.917959  0.011622  0.918040
# amlsim_31         0.954970  0.004924     0.972888  0.003144  0.963078
# amlsim_51         0.936239  0.005529     0.957233  0.006170  0.946187
#
#                      Ilicit Precision           Ilicit Recall            \
#                  std             mean       std          mean       std
# dataset
# amlsim_101  0.001997         0.930039  0.005641      0.858824  0.018166
# amlsim_201  0.006829         0.918473  0.010095      0.843627  0.023842
# amlsim_31   0.004070         0.954970  0.004924      0.987255  0.004736
# amlsim_51   0.003878         0.936239  0.005529      0.943137  0.014468
#
#            Ilicit F1
#                 mean       std
# dataset
# amlsim_101  0.866425  0.003798
# amlsim_201  0.843801  0.013032
# amlsim_31   0.950247  0.005372
# amlsim_51   0.913577  0.006248

# %% [markdown]
# ## Calculate boostrap CIs

# %%
dataset_bootstrap_scores = {}
metrics = [col for col in all_raw_scores_df.columns if col != 'dataset']
for dataset in all_raw_scores_df.dataset.unique():
    dataset_scores = all_raw_scores_df[all_raw_scores_df.dataset == dataset]
    for metric in metrics:
        boostrap_avg_ci, bootstrap_std_ci = model_metrics.get_confidence_intervals(dataset_scores[metric], n_repeats=config.n_repeats)
        dataset_bootstrap_scores[(dataset, metric)] = {
            "avg": boostrap_avg_ci,
            "std": bootstrap_std_ci
        }
dataset_bootstrap_scores_df = pd.DataFrame(dataset_bootstrap_scores).T

# %%
dataset_bootstrap_scores_df.round(3)
# Out:
#                                avg    std
# amlsim_31  Macro Precision   0.955  0.011
#            Macro Recall      0.973  0.007
#            Macro F1          0.963  0.009
#            Ilicit Precision  0.955  0.011
#            Ilicit Recall     0.987  0.011
#            Ilicit F1         0.950  0.012
# amlsim_101 Macro Precision   0.930  0.013
#            Macro Recall      0.923  0.019
#            Macro F1          0.926  0.005
#            Ilicit Precision  0.930  0.013
#            Ilicit Recall     0.859  0.041
#            Ilicit F1         0.866  0.009
# amlsim_51  Macro Precision   0.936  0.013
#            Macro Recall      0.957  0.014
#            Macro F1          0.946  0.009
#            Ilicit Precision  0.936  0.013
#            Ilicit Recall     0.943  0.033
#            Ilicit F1         0.914  0.014
# amlsim_201 Macro Precision   0.918  0.023
#            Macro Recall      0.918  0.026
#            Macro F1          0.918  0.015
#            Ilicit Precision  0.918  0.023
#            Ilicit Recall     0.844  0.054
#            Ilicit F1         0.844  0.029
